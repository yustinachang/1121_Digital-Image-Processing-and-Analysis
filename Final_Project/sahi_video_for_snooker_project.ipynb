# %% [markdown]
# <a href="https://colab.research.google.com/github/yustinachang/1121_Digital-Image-Processing-and-Analysis/blob/main/Final_Project/sahi_video_for_snooker_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/snooker_project.zip -d /content/drive/MyDrive/snooker_project
# Out:
# Archive:  /content/drive/MyDrive/snooker_project.zip
#    creating: /content/drive/MyDrive/snooker_project/snooker_project/
#    creating: /content/drive/MyDrive/snooker_project/snooker_project/train/
#   inflating: /content/drive/MyDrive/snooker_project/snooker_project/train/results.png
#   inflating: /content/drive/MyDrive/snooker_project/snooker_project/train/PR_curve.png
#   inflating: /content/drive/MyDrive/snooker_project/snooker_project/train/train_batch2.jpg
#   inflating: /content/drive/MyDrive/snooker_project/snooker_project/train/labels.jpg
#   inflating: /content/drive/MyDrive/snooker_project/snooker_project/train/val_batch1_labels.jpg
#   inflating: /content/drive/MyDrive/snooker_project/snooker_project/train/args.yaml
#   inflating: /content/drive/MyDrive/snooker_project/snooker_project/train/train_batch1802.jpg
#   inflating: /content/drive/MyDrive/snooker_project/snooker_project/train/train_batch0.jpg
# ...

# %%
# Clone ultralytics repo
# !git clone https://github.com/ultralytics/ultralytics

# Install dependencies
# !pip install sahi ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 23932, done.
# remote: Counting objects: 100% (977/977), done.
# remote: Compressing objects: 100% (695/695), done.
# remote: Total 23932 (delta 627), reused 494 (delta 282), pack-reused 22955
# Receiving objects: 100% (23932/23932), 14.36 MiB | 15.87 MiB/s, done.
# Resolving deltas: 100% (16720/16720), done.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.6/749.6 kB 16.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 14.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 55.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 62.4 MB/s eta 0:00:00
# ...

# %%
# cd to local directory
# %cd /content/ultralytics/examples/YOLOv8-SAHI-Inference-Video

# !python yolov8_sahi.py --source "/content/drive/MyDrive/video.mp4" --save-img --weights "/content/drive/MyDrive/snooker_project/snooker_project/train/weights/best.pt"
# Out:
# /content/ultralytics/examples/YOLOv8-SAHI-Inference-Video
# Performing prediction on 6 number of slices.
# Performing prediction on 6 number of slices.
# Performing prediction on 6 number of slices.
# Performing prediction on 6 number of slices.
# Performing prediction on 6 number of slices.
# Performing prediction on 6 number of slices.
# Performing prediction on 6 number of slices.
# Performing prediction on 6 number of slices.
# Performing prediction on 6 number of slices.
# Performing prediction on 6 number of slices.
# Performing prediction on 6 number of slices.
# Performing prediction on 6 number of slices.
# Performing prediction on 6 number of slices.
# Performing prediction on 6 number of slices.
# Performing prediction on 6 number of slices.
# Performing prediction on 6 number of slices.
# Performing prediction on 6 number of slices.
# Performing prediction on 6 number of slices.
# Performing prediction on 6 number of slices.
# Performing prediction on 6 number of slices.
# ...
